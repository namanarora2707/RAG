# %% [markdown]
# ### Data Ingestion

# %% [markdown]
# ### Document Structure

# %%
from langchain_core.documents import Document

# %%
doc=Document(
    page_content="this is the main text content I am using to create RAG",
    metadata={
        "source": "file1.txt",
        "pages":1,
        "author":"naman",
        "date_created":"2024-10-10"
    }
)
doc
# Out:
# Document(metadata={'source': 'file1.txt', 'pages': 1, 'author': 'naman', 'date_created': '2024-10-10'}, page_content='this is the main text content I am using to create RAG')

# %%
# Create a simple txt files
import os
os.makedirs("../data/text_files", exist_ok=True)

# %%
### Text Loader
from langchain_community.document_loaders import TextLoader

loader =TextLoader("../data/text_files/python_intro.txt", encoding="utf-8")
documents = loader.load()
print(documents)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content="beuhekjdjkerbm fbjheh fj jergfjhrb ejhdb fnm bcjebfdjbg jdh\nedhgevdfhvaewhms agdb'\ndkhevwhjf kjeag fkjh \niedewvfjhav efjhgjegfj hef\ndaed gnhedvhnfbmhbdfc\nefdvchvdcjhgbljdcghjrjdfoewf;c dfhbv\n kjhdfvjhevfdjkbldjf\n efv hjearg fjlaeg fjg fljcuh\n fv khergfjcgaewkjfgjdchf\n d vehgdvcaekgfhg aeriludhf edhgevdfhvaewhmsfvk rfgkjerg\n dvchgdfjfegjlafcha\n uygrefjg ajeg\n dvhahfdgv jewfg vjewgdflch\n f gedvkfjgew hjdsgvfjsd\n e dogyewudyg fewhkjgf jeg fcousd\nuge jyf gckhaewsydgckasjdh\n fogcv hakgscdvkhsdg kjsd\n feg jewhgf kuarweg\n huydgsjydguewgf\n efoy grajuag iufhe\n  yjogf ojagr u gfca'fryfr\n  rudfgf w\n  pewgdaufa\n  sd0pygfof\n  fgjdaf\n  [aeiwpigaoeofa\n  cayfod\n  fogcvagfud[s\n  fipawegc\n  DDSGDOFJD \n  DGHDOSAH\n  gayufh laj\n  agr'iufheafg]]")]

# %%
### Directory Loader
from langchain_community.document_loaders import DirectoryLoader
## load all the text files from a directory
dir_loader=DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt",
    loader_cls=TextLoader,
    loader_kwargs={"encoding":"utf-8"},
    show_progress=False
    )

documents=dir_loader.load()
documents
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\python_intro.txt'}, page_content="beuhekjdjkerbm fbjheh fj jergfjhrb ejhdb fnm bcjebfdjbg jdh\nedhgevdfhvaewhms agdb'\ndkhevwhjf kjeag fkjh \niedewvfjhav efjhgjegfj hef\ndaed gnhedvhnfbmhbdfc\nefdvchvdcjhgbljdcghjrjdfoewf;c dfhbv\n kjhdfvjhevfdjkbldjf\n efv hjearg fjlaeg fjg fljcuh\n fv khergfjcgaewkjfgjdchf\n d vehgdvcaekgfhg aeriludhf edhgevdfhvaewhmsfvk rfgkjerg\n dvchgdfjfegjlafcha\n uygrefjg ajeg\n dvhahfdgv jewfg vjewgdflch\n f gedvkfjgew hjdsgvfjsd\n e dogyewudyg fewhkjgf jeg fcousd\nuge jyf gckhaewsydgckasjdh\n fogcv hakgscdvkhsdg kjsd\n feg jewhgf kuarweg\n huydgsjydguewgf\n efoy grajuag iufhe\n  yjogf ojagr u gfca'fryfr\n  rudfgf w\n  pewgdaufa\n  sd0pygfof\n  fgjdaf\n  [aeiwpigaoeofa\n  cayfod\n  fogcvagfud[s\n  fipawegc\n  DDSGDOFJD \n  DGHDOSAH\n  gayufh laj\n  agr'iufheafg]]")]
